# %% [markdown]
# # Self-Consistency Sampling
#
# Self-consistency sampling is an advanced prompt engineering technique that enhances the reasoning capabilities of LLMs. This method builds upon chain-of-thought prompting by introducing diversity and consistency checks into the reasoning process. Instead of relying on a single output, self-consistency sampling generates multiple reasoning paths for a given problem. It does this by using temperature sampling or other decoding strategies to produce a variety of potential solutions. The key insight is that while individual reasoning attempts may contain errors, the correct answer is likely to appear consistently across multiple attempts. After generating these diverse paths, the technique aggregates the results, typically by selecting the most frequent answer.
#
# This approach leverages the model's ability to approach problems from different angles, potentially overcoming biases or errors present in any single reasoning attempt. Self-consistency sampling is particularly effective for complex reasoning tasks, such as mathematical problem-solving or multi-step logical deductions, where it can significantly improve accuracy without requiring any additional training of the underlying model. By embracing variability in the model's outputs, this technique offers a robust way to enhance the reliability and performance of language models in reasoning tasks.

# %% [markdown]
# ### Self-Consistency Improves Chain of Thought Reasoning in Language Models
#
# This paper introduces a novel decoding strategy called "self-consistency" to improve chain-of-thought reasoning in large language models. The method works by first prompting the model with chain-of-thought exemplars, then sampling multiple diverse reasoning paths from the model's decoder instead of greedily decoding a single path. Finally, it marginalizes out the reasoning paths to find the most consistent answer among the sampled outputs.
#
# This approach leverages the intuition that complex reasoning tasks often have multiple valid paths to the correct answer, and correct reasoning tends to converge on consistent conclusions. The authors demonstrate that self-consistency significantly improves performance across a range of arithmetic and commonsense reasoning tasks, outperforming existing methods like sample-and-rank, beam search, and ensemble approaches. They show substantial gains on benchmarks such as GSM8K (+17.9%), SVAMP (+11.0%), AQuA (+12.2%), StrategyQA (+6.4%), and ARC-challenge (+3.9%). Importantly, self-consistency requires no additional training or fine-tuning and works with off-the-shelf language models, making it a simple yet effective method for enhancing reasoning capabilities in large language models.
#
# > [Self-Consistency Improves Chain of Thought Reasoning in Language Models](https://arxiv.org/abs/2203.11171) by Wang et al., (2023)

# %%
import asyncio
from openai import AsyncOpenAI
import nest_asyncio
from collections import Counter
import json


# Initialize the AsyncOpenAI client
client = AsyncOpenAI()

nest_asyncio.apply() # to run in a jupyter notebook async

async def generate_reasoning_path(question, temperature=0.7):
    """Generates a reasoning path using the OpenAI API asynchronously."""
    response = await client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": """You are a helpful assistant that provides step-by-step reasoning for questions. Provide a step-by-step reasoning and final answer as keys in JSON step_by_step_reasoning, and final_answer."""},
            {"role": "user", "content": f"{question}"}
        ],
        temperature=temperature,
        max_tokens=1000
    )
    return response.choices[0].message.content

def extract_answer(reasoning_path):
    """Extracts the final answer from a reasoning path."""
    try:
        parsed_json = json.loads(reasoning_path)
        return parsed_json.get('final_answer', '').replace('$', '')
    except json.JSONDecodeError:
        return ""

async def self_consistency(question, num_samples=5):
    """Implements the self-consistency method using the OpenAI API asynchronously."""
    tasks = [generate_reasoning_path(question) for _ in range(num_samples)]
    sampled_paths = await asyncio.gather(*tasks)
    answers = [extract_answer(path) for path in sampled_paths]
    most_common_answer = Counter(answers).most_common(1)[0][0]
    return most_common_answer, answers, sampled_paths

# Example usage
async def main():
    question = """Q: If there are 3 cars in the parking
    lot and 2 more cars arrive, how many
    cars are in the parking lot?
    A: {"step_by_step_reasoning": "There are 3 cars in the parking lot already. 2 more arrive. Now there are 3 + 2 = 5 cars. The answer is 5.", "final_answer": "5"}

    Q: A factory produces widgets and gadgets. Each widget requires 3 units of material A and 2 units of material B. Each gadget requires 2 units of material A and 4 units of material B. The factory has 180 units of material A and 160 units of material B available. If the profit on each widget is $12 and on each gadget is $15, what is the maximum profit the factory can make?
    A:"""
    final_answer, answers, reasoning_paths = await self_consistency(question, num_samples=5)

    print(f"The most consistent answer is: {final_answer}")
    print("List of answers:")
    for i, answer in enumerate(answers, 1):
        print(f"Answer {i}: {answer}")
    print("\nReasoning paths:")
    for i, path in enumerate(reasoning_paths, 1):
        print(f"\nPath {i}:")
        print(path)

# Run the async main function
asyncio.run(main())
# Out:
# The most consistent answer is: 825
# List of answers:
# Answer 1: 825
# Answer 2: 825
# Answer 3: 825
# Answer 4:
# Answer 5:
#
# Reasoning paths:
#
# Path 1:
# {
#     "step_by_step_reasoning": [
#         "Step 1: Define the variables:",
#         "Let W be the number of widgets produced.",
#         "Let G be the number of gadgets produced.",
#
#         "Step 2: Set up the constraints based on the material requirements and availability:",
#         "Each widget requires 3 units of material A, so 3W units of material A are used for widgets.",
#         "Each gadget requires 2 units of material A, so 2G units of material A are used for gadgets.",
#         "The total units of material A used are 3W + 2G, and this must be less than or equal to 180:",
#         "3W + 2G ≤ 180",
#
#         "Each widget requires 2 units of material B, so 2W units of material B are used for widgets.",
#         "Each gadget requires 4 units of material B, so 4G units of material B are used for gadgets.",
#         "The total units of material B used are 2W + 4G, and this must be less than or equal to 160:",
#         "2W + 4G ≤ 160",
#
#         "Step 3: Set up the profit equation:",
#         "Profit from widgets = 12W",
#         "Profit from gadgets = 15G",
#         "Total profit (P) = 12W + 15G",
#
#         "Step 4: Solve the system of inequalities for the maximum profit:",
#         "We need to find the values of W and G that maximize the profit function P = 12W + 15G under the constraints 3W + 2G ≤ 180 and 2W + 4G ≤ 160.",
#
#         "Step 5: Find the feasible region:",
#         "We can graph the constraints to find the feasible region. However, let's use substitution or elimination method to find the intersection points of the constraints.",
#
#         "Constraint 1: 3W + 2G = 180",
#         "Constraint 2: 2W + 4G = 160",
#
#         "Solve Constraint 2 for G: 2W + 4G = 160 -> G = (160 - 2W) / 4 = 40 - 0.5W",
#         "Substitute this in Constraint 1:",
#         "3W + 2(40 - 0.5W) = 180",
#         "3W + 80 - W = 180",
#         "2W = 100",
#         "W = 50",
#         "Substitute W = 50 in G = 40 - 0.5W:",
#         "G = 40 - 0.5(50) = 40 - 25 = 15",
#
#         "Intersection point: (W, G) = (50, 15)",
#
#         "Step 6: Check the vertices of the feasible region:",
#         "The vertices are (0, 0), (0, 40), (50, 15), and (60, 0).",
#
#         "Calculate Profit at each vertex:",
#         "Vertex (0, 0): P = 12(0) + 15(0) = 0",
#         "Vertex (0, 40): P = 12(0) + 15(40) = 600",
#         "Vertex (50, 15): P = 12(50) + 15(15) = 600 + 225 = 825",
#         "Vertex (60, 0): P = 12(60) + 15(0) = 720",
#
#         "Step 7: Determine the maximum profit:",
#         "The maximum profit is 825 at the vertex (50, 15)."
#     ],
#     "final_answer": "825"
# }
#
# Path 2:
# {
#     "step_by_step_reasoning": [
#         "Step 1: Define variables. Let w be the number of widgets and g be the number of gadgets.",
#         "Step 2: Set up the material constraints. Each widget requires 3 units of material A and 2 units of material B. Each gadget requires 2 units of material A and 4 units of material B.",
#         "Step 3: Write the constraints based on the available materials:",
#         "3w + 2g ≤ 180 (for material A)",
#         "2w + 4g ≤ 160 (for material B)",
#         "Step 4: Write the profit function to maximize. The profit from widgets is $12 per widget and from gadgets is $15 per gadget, so the profit function is:",
#         "Profit = 12w + 15g",
#         "Step 5: Solve the system of inequalities using linear programming techniques. We need to find the feasible region defined by the constraints and then find the point within this region that maximizes the profit function.",
#         "Step 6: To find the vertices of the feasible region, solve the system of equations formed by the intersections of the constraint lines:",
#         "From 3w + 2g = 180 and 2w + 4g = 160, solve for w and g.",
#         "Step 7: Solve 3w + 2g = 180 for g:",
#         "g = (180 - 3w) / 2",
#         "Step 8: Substitute this into 2w + 4g = 160:",
#         "2w + 4((180 - 3w) / 2) = 160",
#         "2w + 360 - 6w = 160",
#         "-4w = -200",
#         "w = 50",
#         "Step 9: Substitute w = 50 into g = (180 - 3w) / 2:",
#         "g = (180 - 3*50) / 2",
#         "g = (180 - 150) / 2",
#         "g = 30 / 2",
#         "g = 15",
#         "Step 10: Verify other points of intersection and boundary conditions.",
#         "Check w = 0: 2g = 160, g = 80 (not feasible, exceeds material A constraint)",
#         "Check g = 0: 3w = 180, w = 60 (not feasible, exceeds material B constraint)",
#         "Check intersection of constraints: 3w + 2g = 180, 2w + 4g = 160",
#         "We have already found w = 50, g = 15 as a feasible point.",
#         "Step 11: Calculate the profit at feasible points:",
#         "For (w, g) = (50, 15): Profit = 12*50 + 15*15 = 600 + 225 = 825",
#         "Step 12: Verify if any other feasible points increase the profit.",
#         "The point (50, 15) lies within the feasible region and maximizes the profit."
#     ],
#     "final_answer": "825"
# }
#
# Path 3:
# {
#   "step_by_step_reasoning": [
#     "Define the variables: Let W be the number of widgets and G be the number of gadgets produced.",
#     "Set up the material constraints based on the units needed for each product and the total available materials:",
#     "3W + 2G <= 180 (constraint for material A)",
#     "2W + 4G <= 160 (constraint for material B)",
#     "Determine the profit function: Profit = 12W + 15G",
#     "Find the feasible region by solving the constraints:",
#     "Convert each inequality constraint into equations to find the boundary lines and intersections:",
#     "3W + 2G = 180",
#     "2W + 4G = 160",
#     "Solve for G in terms of W in each equation:",
#     "G = (180 - 3W) / 2",
#     "G = (160 - 2W) / 4",
#     "Find the intersection points by solving the system of equations formed by the boundary lines:",
#     "Set (180 - 3W) / 2 = (160 - 2W) / 4",
#     "Multiply both sides by 4 to clear the denominator: 2(180 - 3W) = 160 - 2W",
#     "360 - 6W = 160 - 2W",
#     "Add 6W to both sides: 360 = 160 + 4W",
#     "Subtract 160 from both sides: 200 = 4W",
#     "Divide by 4: W = 50",
#     "Substitute W = 50 into one of the original constraints to find G:",
#     "G = (180 - 3(50)) / 2",
#     "G = (180 - 150) / 2",
#     "G = 30 / 2",
#     "G = 15",
#     "Identify the feasible region's corner points (W, G): These are (0, 0), (60, 0), (0, 40), and (50, 15), obtained from solving the constraints and finding intersections with the axes.",
#     "Calculate the profit at each corner point:",
#     "At (0, 0): Profit = 12(0) + 15(0) = 0",
#     "At (60, 0): Profit = 12(60) + 15(0) = 720",
#     "At (0, 40): Profit = 12(0) + 15(40) = 600",
#     "At (50, 15): Profit = 12(50) + 15(15) = 600 + 225 = 825",
#     "The maximum profit is obtained at the point (50, 15) with a profit of $825."
#   ],
#   "final_answer": "825"
# }
#
# Path 4:
# {
#   "step_by_step_reasoning": "To maximize the profit, we need to determine how many widgets and gadgets the factory can produce given the constraints on materials A and B. Let's denote the number of widgets produced as W and the number of gadgets produced as G.
#
#   Step 1: Set up the material constraints:
#   - Each widget requires 3 units of material A and each gadget requires 2 units of material A:
#     3W + 2G <= 180
#   - Each widget requires 2 units of material B and each gadget requires 4 units of material B:
#     2W + 4G <= 160
#
#   Step 2: Set up the profit function:
#   - Profit on each widget is $12 and on each gadget is $15:
#     Profit = 12W + 15G
#
#   Step 3: Solve the system of linear inequalities to find the feasible region:
#   - Simplify the constraints:
#     3W + 2G <= 180
#     2W + 4G <= 160
#
#   Step 4: Find the intercepts:
#   - For 3W + 2G <= 180:
#     If W = 0, G = 90
#     If G = 0, W = 60
#   - For 2W + 4G <= 160:
#     If W = 0, G = 40
#     If G = 0, W = 80
#
#   Step 5: Identify the vertices of the feasible region (where the constraints intersect):
#   - The feasible region is bounded by the points (0, 0), (0, 40), (40, 0), and the intersection of 3W + 2G = 180 and 2W + 4G = 160.
#
#   Step 6: Find the intersection point:
#   - Solve the system of equations:
#     3W + 2G = 180
#     2W + 4G = 160
#     Multiply the first equation by 2 and the second by 1:
#     6W + 4G = 360
#     2W + 4G = 160
#     Subtract the second equation from the first:
#     4W = 200
#     W = 50
#     Substitute W = 50 into 3W + 2G = 180:
#     3(50) + 2G = 180
#     150 + 2G = 180
#     2G = 30
#     G = 15
#
#   Step 7: Evaluate the profit at each vertex:
#   - At (0, 0): Profit = 12(0) + 15(0) = $0
#   - At (0, 40): Profit = 12(0) + 15(40) = $600
#   - At (40, 0): Profit = 12(40) + 15(0) = $480
#   - At (50, 15): Profit = 12(50) + 15(15) = $600 + $225 = $825
#
#   Step 8: Determine the maximum profit:
#   - The maximum profit is $825 at the point (50, 15).
#
#   The factory should produce 50 widgets and 15 gadgets to achieve the maximum profit of $825.",
#   "final_answer": "The maximum profit the factory can make is $825."
# }
#
# Path 5:
# {
#     "step_by_step_reasoning": "To find the maximum profit, we need to determine how many widgets (W) and gadgets (G) the factory can produce given the constraints on materials A and B. We will use linear programming to solve this.
#
# 1. Define the variables:
#    - W: Number of widgets produced
#    - G: Number of gadgets produced
#
# 2. Write the constraints based on material requirements:
#    - 3W + 2G ≤ 180 (for material A)
#    - 2W + 4G ≤ 160 (for material B)
#
# 3. Write the objective function (profit):
#    - Maximize Profit = 12W + 15G
#
# 4. Identify the feasible region by solving the constraints:
#    - From the first constraint: G = (180 - 3W) / 2
#    - From the second constraint: G = (160 - 2W) / 4
#
# 5. Determine the intersection points of the constraints:
#    - At W = 0: G = 90 (from the first constraint)
#    - At W = 0: G = 40 (from the second constraint)
#
#    - Setting 3W + 2G = 180 and 2W + 4G = 160:
#      Multiply the first equation by 2 and the second by 1:
#      - 6W + 4G = 360
#      - 2W + 4G = 160
#      Subtract the second from the first:
#      - 4W = 200
#      - W = 50
#      - Substitute W = 50 into the first constraint: 3(50) + 2G = 180
#      - 150 + 2G = 180
#      - 2G = 30
#      - G = 15
#
#    - Additional intersection points from G = 0:
#      - 3W = 180 -> W = 60 (Constraint 1)
#      - 2W = 160 -> W = 80 (Constraint 2)
#
# 6. Evaluate the profit at the feasible points (0,40), (50,15), (60,0):
#    - Profit at (0,40): 12(0) + 15(40) = $600
#    - Profit at (50,15): 12(50) + 15(15) = $945
#    - Profit at (60,0): 12(60) + 15(0) = $720
#
# 7. The maximum profit is $945 when producing 50 widgets and 15 gadgets.",
#     "final_answer": "945"
# }
